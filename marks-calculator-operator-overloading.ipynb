# %%
class Marks():

    def __init__(self, marks):
        self.marks = marks

    def __add__(self, other):
        return self.marks + other.marks

science = Marks(75)
history = Marks(55)

print(science + history)
# Out:
# 130
